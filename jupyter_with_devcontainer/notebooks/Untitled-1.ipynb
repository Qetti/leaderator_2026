# %% [markdown]
# jupyter notebook --ip=0.0.0.0 --port=8888 --no-browser --allow-root --NotebookApp.token=''

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.12.13 (main, Apr  7 2026, 04:52:21) [GCC 14.2.0]
